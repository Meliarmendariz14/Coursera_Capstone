# %% [markdown]
# # The Battle of Neighborhoods | Business Problem/ Introduction

# %% [markdown]
# ## Introduction:

# %% [markdown]
# Many families, mainly for work reasons, must migrate from countries or cities.
# To help families who must go to the city of Toronto, I will conduct an analysis of the best neighborhoods.
# In this project, comparative data from different neighborhoods will be introduced, such as proximity to schools, restaurants, security, etc.

# %% [markdown]
# ## Work Flow:
